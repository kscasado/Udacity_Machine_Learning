# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('QB2014.csv', encoding='utf8', engine='python')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 0 to 74
# Data columns (total 21 columns):
# Name        75 non-null object
# Team        75 non-null object
# G           75 non-null int64
# QBRat       75 non-null float64
# Comp        75 non-null int64
# Att         75 non-null int64
# Pct         75 non-null object
# PassYds     75 non-null int64
# Y/G         75 non-null float64
# Y/A         75 non-null object
# TD          75 non-null int64
# Int         75 non-null int64
# Rush        75 non-null int64
# RushYds     75 non-null int64
# RushY/G     75 non-null float64
# RushAvg     75 non-null object
# RushTD      75 non-null int64
# Sack        75 non-null int64
# YdsL        75 non-null int64
# Fum         75 non-null int64
# FumL        75 non-null int64
# dtypes: float64(3), int64(13), object(5)
# memory usage: 12.9+ KB

# %%
df = df[df['QBRat ']>0]

# %%
df['FFPoints']= (df['PassYds ']/4 + df['TD ']*4 + df['RushYds']/10+df['RushTD ']*4 
    -df['Int ']*2)

df = df.sort_values(['FFPoints'],ascending=False)
df
# Out:
#                    Name Team   G  QBRat   Comp   Att   Pct   PassYds    Y/G   \
# 12          Andrew Luck  IND  16    96.5    380   616  61.7      4761  297.6
# 4    Ben Roethlisberger  PIT  16   103.3    408   608  67.1      4952  309.5
# 11           Drew Brees  NOR  16    97.0    456   659  69.2      4952  309.5
# 7        Peyton Manning  DEN  16   101.5    395   597  66.2      4727  295.4
# 2         Aaron Rodgers  GNB  16   112.2    341   520  65.6      4381  273.8
# 17            Matt Ryan  ATL  16    93.9    415   628  66.1      4694  293.4
# 21          Eli Manning  NYG  16    92.1    379   601  63.1      4410  275.6
# 18        Philip Rivers  SDG  16    93.8    379   570  66.5      4286  267.9
# 10            Tom Brady  NWE  16    97.4    373   582  64.1      4109  256.8
# 32     Matthew Stafford  DET  16    85.7    363   602  60.3      4257  266.1
# 20       Ryan Tannehill  MIA  16    92.8    392   590  66.4      4045  252.8
# ...

# %%
dataArray = df.values
df.info()
df = df.fillna(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 12 to 69
# Data columns (total 22 columns):
# Name        72 non-null object
# Team        72 non-null object
# G           72 non-null int64
# QBRat       72 non-null float64
# Comp        72 non-null int64
# Att         72 non-null int64
# Pct         72 non-null object
# PassYds     72 non-null int64
# Y/G         72 non-null float64
# Y/A         72 non-null object
# TD          72 non-null int64
# Int         72 non-null int64
# Rush        72 non-null int64
# RushYds     72 non-null int64
# RushY/G     72 non-null float64
# RushAvg     72 non-null object
# RushTD      72 non-null int64
# Sack        72 non-null int64
# YdsL        72 non-null int64
# Fum         72 non-null int64
# FumL        72 non-null int64
# FFPoints    72 non-null float64
# dtypes: float64(4), int64(13), object(5)
# memory usage: 12.9+ KB

# %%
y = dataArray[:,[21]]
dataArray
#dataArray=np.delete(dataArray,21,1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-ba9695be5f60> in <module>()
# ----> 1 y = dataArray[:,[21]]
#       2 dataArray
#       3 dataArray=np.delete(dataArray,20,1)
#
# IndexError: index 21 is out of bounds for axis 1 with size 20

# %%
dataArray=np.delete(dataArray,0,1)
dataArray=np.delete(dataArray,0,1)

dataArray
# Out:
# array([[16, 96.5, 380, ..., 13, 6, 1357.55],
#        [16, 103.3, 408, ..., 9, 5, 1350.7],
#        [16, 97.0, 456, ..., 7, 3, 1346.8],
#        ...,
#        [1, 42.4, 1, ..., 0, 0, 1.65],
#        [1, 79.2, 1, ..., 0, 0, 0.0],
#        [1, 39.6, 0, ..., 0, 0, 0.0]], dtype=object)

# %%
from sklearn.cross_validation import train_test_split
train_x,test_x,train_y, test_y = train_test_split(dataArray,y, test_size = 0.5)

# %%
from sklearn.linear_model import LogisticRegression
logReg = LogisticRegression().fit(train_x,train_y.ravel())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-41a251170151> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
# ----> 2 logReg = LogisticRegression().fit(train_x,train_y.ravel())
#
# /Users/kcasado/anaconda/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1140
#    1141         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1142                          order="C")
#    1143         check_classification_targets(y)
#    1144         self.classes_ = np.unique(y)
#
# /Users/kcasado/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...
